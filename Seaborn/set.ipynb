# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style='dark', palette='muted', font_scale=1.5)
sns.barplot(x=['A','B','C','D','E'], y=[10,20,30,40,50])
# Out:
# <AxesSubplot: >
